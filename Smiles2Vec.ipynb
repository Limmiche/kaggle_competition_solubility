# %%
import pandas as pd
import numpy as np
import deepchem as dc
from deepchem.models import Smiles2Vec

# %%
df_train = pd.read_csv("Data/train.csv")

# %%
df_train.drop(columns='Id', inplace=True)
df_train
# Out:
#                                                   smiles  sol_category
# 0      Cc1nc(N2CCN(C(=O)Nc3ccc(F)cc3F)CC2)cc(-n2ccnc2)n1             0
# 1            CCN(CC)[C@H]1CCN(C(=O)Cc2nc(C(C)C)c(C)s2)C1             0
# 2                    CNC(=O)CNC(=O)c1c(-n2cccc2)sc(C)c1C             0
# 3           CC(C)(C)c1ccc(CSc2cnn(C(C)(C)C)c(=O)c2Cl)cc1             0
# 4            CC[C@H](NC(=O)c1ccnc(-n2ccnc2)c1)c1ccccc1OC             0
# ...                                                  ...           ...
# 70706        O=C(NCCCc1nc(=O)[nH][nH]1)[C@H]1CCC(F)(F)C1             2
# 70707          Cc1ccc(C(=O)NC2CCCC2)cc1S(=O)(=O)N1CCOCC1             2
# 70708      COCCN1CCC(CN(C)S(=O)(=O)c2cccc(C(F)(F)F)c2)C1             2
# 70709  O=C(Nc1ccc(F)cc1)NC1CCN(C(=O)Cc2cnn(-c3ccccc3)...             2
# 70710        COC[C@H](C)NC(=O)N1CCN(c2nnnn2-c2ccccc2)CC1             2
#
# [70711 rows x 2 columns]

# %%
emb50 = df_train.copy(deep=True)
emb100 = df_train.copy(deep=True)
emb150 = df_train.copy(deep=True)
emb200 = df_train.copy(deep=True)

emb50['vectors'] = Smiles2Vec(df_train['smiles'])
emb100['vectors'] = Smiles2Vec(df_train['smiles'], embedding_dim=100)
emb150['vectors'] = Smiles2Vec(df_train['smiles'], embedding_dim=150)
emb200['vectors'] = Smiles2Vec(df_train['smiles'], embedding_dim=200)

# %%
emb50
# Out:
#                                                   smiles  sol_category  \
# 0      Cc1nc(N2CCN(C(=O)Nc3ccc(F)cc3F)CC2)cc(-n2ccnc2)n1             0
# 1            CCN(CC)[C@H]1CCN(C(=O)Cc2nc(C(C)C)c(C)s2)C1             0
# 2                    CNC(=O)CNC(=O)c1c(-n2cccc2)sc(C)c1C             0
# 3           CC(C)(C)c1ccc(CSc2cnn(C(C)(C)C)c(=O)c2Cl)cc1             0
# 4            CC[C@H](NC(=O)c1ccnc(-n2ccnc2)c1)c1ccccc1OC             0
# ...                                                  ...           ...
# 70706        O=C(NCCCc1nc(=O)[nH][nH]1)[C@H]1CCC(F)(F)C1             2
# 70707          Cc1ccc(C(=O)NC2CCCC2)cc1S(=O)(=O)N1CCOCC1             2
# 70708      COCCN1CCC(CN(C)S(=O)(=O)c2cccc(C(F)(F)F)c2)C1             2
# 70709  O=C(Nc1ccc(F)cc1)NC1CCN(C(=O)Cc2cnn(-c3ccccc3)...             2
# 70710        COC[C@H](C)NC(=O)N1CCN(c2nnnn2-c2ccccc2)CC1             2
#
#                                                  vectors
# 0      <deepchem.models.chemnet_models.Smiles2Vec obj...
# ...

# %%
#emb50.to_csv('Temp/emb50.csv')
#emb100.to_csv('Temp/emb50.csv')
#emb150.to_csv('Temp/emb50.csv')
#emb200.to_csv('Temp/emb50.csv')

# %%
Smiles2Vec(df_train['smiles'], embedding_dim=100).predict('whatever  is here necessary')
# Out:
# ['__class__',
#  '__del__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_build_graph',
#  '_built',
#  '_compute_model',
#  '_create_assignment_map',
#  '_create_gradient_fn',
#  '_create_inputs',
#  '_create_training_ops',
#  '_create_value_map',
#  '_ensure_built',
#  '_gradient_fn_for_vars',
#  '_inputs_built',
#  '_log_scalar_to_tensorboard',
#  '_loss_fn',
#  '_loss_outputs',
#  '_other_outputs',
#  '_output_functions',
#  '_predict',
#  '_prediction_outputs',
#  '_prepare_batch',
#  '_training_ops_built',
#  '_variance_outputs',
#  'batch_size',
#  'char_to_idx',
#  'compute_saliency',
#  'default_generator',
# ...
